# %% [markdown]
# # Car ads annotation on 3 Jakobson's functions of language dimensions
#
# We annotate the car ads in this way:
#
# - `informativeness` using 5 point Likert scale
# - `expressiveness` using 5 point Likert scale
# - `phatic` using 5 point Likert scale
# - `dominant_dimension` this is a classification that choose the most prevalent dimension
# - `dominant_dimension_score` using 5 point Likert scale only the dimension that was chose before
#
# Architecture:
#
# 1. Gemma 4 as `Gemma_annotater`
# 2. Mistral as `Mistral_annotater`
# 3. Router decides `accept`, `send_to_review`, or `ask_human`

# %% [markdown]
# ## Theory Notes
#
# They are based on Roman Jakobson functions of language in his 1960 "Closing Statement: Linguistics and Poetics,
#
# - `informativeness`: referential or factual function, pointing to the real world and giving concrete information (Focused on the Context (the topic)) (Jakobson, 1960)
# - `expressiveness`: emotive function, where the initiator expresses feeling, desire, admiration, aspiration, or emotional tone ( Focused on the addresser (sender)) (Jakobson, 1960)
# - `phatic`:  relationship-maintaining function  or discontinue communication, mostly used in social interaction, where the ad creates or maintains an affective bond with the customer (Focused on the Contact (the channel)) (Jakobson, 1960)
#
# Important design choice:
#
# - we do **not** collapse informativeness and expressiveness into one single axis first;
# - we score all three dimensions independently from 1 to 5;
# - only after that do we derive the dominant dimension.
#
# Reference
#
# Jakobson, Roman. "Linguistics and Poetics". Volume III Poetry of Grammar and Grammar of Poetry, Berlin, Boston: De Gruyter Mouton, 1981, pp. 18-51. https://doi.org/10.1515/9783110802122.18

# %% [markdown]
# #Imports
# They are specialy made for google colab if you are using something else please comment drive.mount function

# %%
from google.colab import drive #this is useful only if you want to access the documents from Google Drive
drive.mount('/content/drive', force_remount=False) #this connects it to your Google Drive to the colab runtime and force_remount is False since we do not want to remount again if Drive is connected

import os
import sys
from pathlib import Path

PROJECT_ROOT = Path("/content/drive/MyDrive/Gliner-Work.Dauphine") #my folder name
DATASET_PATH = PROJECT_ROOT / "annotation_working_master_human_2100_seed.csv" # / joins folder and file names
OUTPUT_DIR = PROJECT_ROOT / "communication_function_outputs" #this is the output file
OUTPUT_DIR.mkdir(parents=True, exist_ok=True) #this is useful to avoid crashes- if file does not exist it creates it, if it exists it does not crash

os.chdir(PROJECT_ROOT) #this change the working director to my current working folder


#this is useful only if you want to add py files
#this checks if Python knows it already if not it adds it at the beginning of Python’s import search path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))


print("PROJECT_ROOT =", PROJECT_ROOT)
print("DATASET_PATH exists =", DATASET_PATH.exists())
print("OUTPUT_DIR =", OUTPUT_DIR)
# Out:
# Mounted at /content/drive
# PROJECT_ROOT = /content/drive/MyDrive/Gliner-Work.Dauphine
# DATASET_PATH exists = True
# OUTPUT_DIR = /content/drive/MyDrive/Gliner-Work.Dauphine/communication_function_outputs

# %% [markdown]
# Import libraries

# %%
import json
import re
import shlex
import subprocess
import pickle
from dataclasses import asdict, dataclass
from functools import lru_cache

import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Settings

# %%
#this is the list with expanded number of columns

TEXT_COLUMNS = [
    "Script",
    "Visuel",
    "Titre",
    "MotsClés",
    "Thème",
    "Signature",
]


#this is using a small a amount of columns to see if there are any differeneces

MISTRAL_FOCUS_COLUMNS = [
    "Script",
    "Visuel",
    "Titre",
    "MotsClés",
    "Signature",
]


#this are th context column, they are not main text ad, they will give some useful info about it
METADATA_COLUMNS = [
    "year",
    "Month",
    "Marque",
    "Produit",
    "Variété",
    "Electric",
    "Hybrid",
    "Support",
    "Format",
    "Agence",
    "length",
]

DIMENSIONS = ["informativeness", "expressiveness", "phatic"] #this are the 3 dimensions of Jackobson
#5-point Likert scale
SCORE_MIN = 1
SCORE_MAX = 5

RUN_REAL_MODELS = True
ROUTER_ACCEPT_THRESHOLD = 0.82  #the threshold for accepting the label
ROUTER_REVIEW_THRESHOLD = 0.60 #the threshold for need to review label
ROUTER_HUMAN_THRESHOLD = 0.40 #the threshold for human need label
ROUTER_MAX_AVG_SCORE_DELTA = 0.75 #this keeps teh model average of the disagree below 0.75 between rating of the 3 dimensions
ROUTER_MAX_HARD_DELTA = 2 # this check for teh highest disagreement on a single score
POLICY_PATH = OUTPUT_DIR / "router_policy.pkl" #this is a pickle file = a saved Python object

# %%
GEMMA_MODEL = "google/gemma-4-E4B-it" #this is the gemma 4 model i will use please change it if you have a more powerful gpu or a worse one, than T4 GPU
#Gemma_Annotater = "google/gemma-4-31B-it" #strongest version
#Gemma_Annotater = "google/gemma-4-E2B-it" #lightest version
MISTRAL_MODEL = "mistralai/Mistral-Small-4-119B-2603-eagle" #this is the mistral model
#Mistral_Annotater = "mistralai/Mistral-7B-v0.1" #this uses less memory, but I do not recommand it for longer texts as mine
MAX_NEW_TOKENS = 600 #this puts a restriction of 600 tokens for the modelm to avoid long answers

print("Gemma model:", GEMMA_MODEL)
print("Mistral model:", MISTRAL_MODEL)
# Out:
# Gemma model: google/gemma-4-E4B-it
# Mistral model: mistralai/Mistral-Small-4-119B-2603-eagle

# %% [markdown]
# #This code block is only for debugging scope only
# This only keeps the variables

# %%
from dataclasses import dataclass, asdict

#I created 3 containers each of them stores main annotations for each ad
@dataclass
class GemmaPrediction:
    row_id: int
    informativeness: int
    expressiveness: int
    phatic: int
    dominant_dimension: str
    dominant_dimension_score: int
    confidence: float
    alternative_dimension: str
    reason: str
    model_name: str

    def to_dict(self):
        return asdict(self)

@dataclass
class MistralDecision:
    row_id: int
    Mistral_informativeness: int
    Mistral_expressiveness: int
    Mistral_phatic: int
    Mistral_dominant_dimension: str
    Mistral_dominant_dimension_score: int
    Mistral_confidence: float
    agrees_with_Gemma: bool
    avg_score_delta: float
    max_score_delta: int
    disagreement_reason: str
    model_name: str

    def to_dict(self):
        return asdict(self)

@dataclass
class RouterDecision:
    row_id: int
    route_action: str
    route_score: float
    route_reason: str

    def to_dict(self):
        return asdict(self)

print("Gemma model:", GEMMA_MODEL)
print("Mistral model:", MISTRAL_MODEL)
print("Max new tokens:", MAX_NEW_TOKENS)
# Out:
# Gemma model: google/gemma-4-E4B-it
# Mistral model: mistralai/Mistral-Small-4-119B-2603-eagle
# Max new tokens: 600

# %% [markdown]
# #Data preprocessing and cleaning

# %% [markdown]
# This is useful for the missing values

# %%
def normalize_text(value):
    if pd.isna(value):
        return ""
    return " ".join(str(value).split()).strip() #okay so we made the output a string, we removed teh spaces and joined them together using one single space and we removed the space from the begining and end

# %% [markdown]
# This loads rows from CSV and filter them

# %%
def load_rows(limit=None, review_status="needs_label", row_ids=None): #how many rows to keep and we keep only reviews labeled with needs_label
    df = pd.read_csv(DATASET_PATH) #reads csv to pandas DF
    df["row_id"] = pd.to_numeric(df["row_id"], errors="coerce").astype("Int64") #this cleans the row_id column, errors turn the value if invalid in missing one

    if review_status is not None and "Review_Status" in df.columns: #If the first is provided and teh second exists
        df = df[df["Review_Status"] == review_status].copy() #then keep only those values, by default rows with needs_label
#this keeps only the rows whose row_id is in the list of IDs
    if row_ids is not None:
        wanted = {int(x) for x in row_ids}
        df = df[df["row_id"].isin(wanted)].copy()
#this line can be useful if you want to try the labeling of only a subset of entries, for this cxhaneg limit value
    if limit is not None:
        df = df.head(limit).copy()

    return df

# %% [markdown]
# This function checks whether your DataFrame contains all the columns you expect and if some are missing, it stops the code with an error listing those missing column names. This can help you avoid mistakes that may need the restart of the code and time and computational costs.

# %%
def require_columns(df, columns):
    missing = [c for c in columns if c not in df.columns] #this contains a list with all the columns name we expected that are not present in DF
    if missing:
        raise ValueError(f"Missing columns in dataset: {missing}") #this is the raised error

# %% [markdown]
# This takes one row of your dataset and turns the selected columns into one clean block of text.

# %%
def build_record_text(row, columns):
    parts = []
    for column in columns:
        text = normalize_text(row.get(column, "")) #if the column exists get its value if not return an empty string
        if text:
            parts.append(f"{column}: {text}") #this creates a dict with var name and its text
    return "\n".join(parts) #this join them together

# %% [markdown]
# This code does the same but for metadata text

# %%
def build_metadata_text(row):
    parts = []
    for column in METADATA_COLUMNS:
        text = normalize_text(row.get(column, ""))
        if text:
            parts.append(f"{column}: {text}")
    return "\n".join(parts)

# %% [markdown]
# This is a quick check

# %%
def build_combined_text(row, columns):
    metadata = build_metadata_text(row) # this builds the metadata block from the row.
    record = build_record_text(row, columns=columns) # this builds the main ad-content block from the selected columns.
    if metadata and record:
        return metadata + "\n\n" + record
    return metadata or record #if one is missing return the one thta exists

preview = load_rows(limit=2, review_status="needs_label") #this loads 2 datasets
require_columns(preview, ["row_id"] + TEXT_COLUMNS + METADATA_COLUMNS) #this check if it contains all columns
preview[["row_id", "Marque", "Produit", "Script", "Visuel"]].head()
# Out:
#       row_id  Marque          Produit  \
# 2100    2100  NISSAN  NISSAN PRESTIGE
# 2101    2101      VW      VW PRESTIGE
#
#                                                  Script  \
# 2100  Voix homme : " NISSAN est fier de vous présent...
# 2101  Voix homme (1) : " Il n'y a rien de tel que ri...
#
#                                                  Visuel
# 2100  Sergio Aguero, nouvel ambassadeur de NISSAN, a...
# 2101  De la naissance de l'Univers à l'art contempor...

# %% [markdown]
# #Annotation rules

# %% [markdown]
# the main instruction text for Gemma or Mistral

# %%
RUBRIC_TEXT = """You are scoring automotive advertisements with three communication dimensions.

Definitions:
- informativeness: the ad's referential or factual function. It gives product facts, technical details, prices, offers, features, specifications, environmental facts, or concrete real-world information.
- expressiveness: the ad's emotive function. The advertiser expresses feelings, desire, admiration, passion, identity, aspiration, beauty, or an emotional tone.
- phatic: the ad's relationship-maintaining function. The language tries to create or maintain a social bond with the customer, using closeness, togetherness, friendliness, companionship, or affective connection.

Scoring scale:
- 1 = almost absent
- 2 = weak trace
- 3 = clearly present but not dominant
- 4 = strong
- 5 = central and unmistakable

Rules:
- Ads are not zero-sum. An ad can be high on more than one dimension.
- Score each dimension independently from 1 to 5.
- Use text, translated text, visual description, and metadata.
- If two or three dimensions tie for the highest score, use dominant_dimension = mixed.
- dominant_dimension_score must equal the highest of the three scores.
- Keep the reason short and concrete.
"""

# %% [markdown]
# This are my supervisor notes please comment this box if you are not in the same situation

# %%
SUPERVISOR_NOTES = """Supervisor notes:
- informative content has a social use because it informs people;
- persuasive content is closer to expressiveness;
- referential language points to the real world;
- expressiveness belongs to the initiator and conveys feeling;
- phatic language helps maintain a social relationship and affective bond with the customer;
- many ads contain both informativeness and expressiveness, so score them separately before deriving a dominant one.
"""

# %% [markdown]
# This function tells the model what JSON structure should return

# %%
def output_schema_text():
    return """Return strict JSON only with:
{
  "informativeness": 1,
  "expressiveness": 1,
  "phatic": 1,
  "dominant_dimension": "informativeness|expressiveness|phatic|mixed",
  "dominant_dimension_score": 1,
  "confidence": 0.0,
  "alternative_dimension": "informativeness|expressiveness|phatic|mixed|",
  "reason": "short explanation"
}
"""

# %% [markdown]
# This cleans and standardizes a dimension name

# %%
#this function can be helpful if the model uses different words and converts them in your official ones
def normalize_dimension_name(value):
    text = str(value or "").strip().lower() #this cleans the input
    aliases = {
        "informative": "informativeness",
        "information": "informativeness",
        "referential": "informativeness",
        "expressive": "expressiveness",
        "emotive": "expressiveness",
        "emotion": "expressiveness",
        "fatiq": "phatic",
        "fatique": "phatic",
        "fatigue": "phatic",
        "phatique": "phatic",
    }
    text = aliases.get(text, text) #if the word is in aliases replace it, if not keep it
    return text if text in DIMENSIONS or text == "mixed" else "" #this returns one of the official dimensions if it is something else returns ""

# %% [markdown]
# This makes sure the score becomes a valid number on your 1 to 5 scale

# %%
def clamp_score(value):
    try:
        score = int(round(float(value))) #converts the input into a number from a decimal to a rounded int
    except Exception: #if model gives something invalid it becomes 1
        score = SCORE_MIN
    return max(SCORE_MIN, min(SCORE_MAX, score)) #this forces the output to stay in the 1 to 5 range

# %% [markdown]
# This function chooses which of the three dimensions is the dominant one

# %%
#this takes a dict and returns a dominant dimension, its score and the second best dimension
def pick_dominant_dimension(scores):
    ranked = sorted(scores.items(), key=lambda item: item[1], reverse=True) #this sort the dict items by score from highest to lowest
    top_label, top_score = ranked[0] #this takes the highest score and its label
    same_top = [label for label, score in ranked if score == top_score] #this creates a list of all lables that have the same top
    alt = ranked[1][0] if len(ranked) > 1 else "" #this takes the second-ranked label
    if len(same_top) > 1: #if more than one dimension shares the top score, the dominant and second domniant dimensions are mixed
        return "mixed", top_score, alt
    return top_label, top_score, alt

# %% [markdown]
# This function takes a raw model output and turns it into a clean, valid prediction dictionary.

# %%
def coerce_prediction_dict(payload, row_id, model_name): #the three argumensts are the row output from the model the ID of the row being annotated and the name of the model that produced the answer
    #this cleans the three scores
    scores = {
        "informativeness": clamp_score(payload.get("informativeness")),
        "expressiveness": clamp_score(payload.get("expressiveness")),
        "phatic": clamp_score(payload.get("phatic")),
    }



#this infer the dominant dimension, top score and alternative dimension
    inferred_dom, inferred_score, inferred_alt = pick_dominant_dimension(scores)

#this cleans it
    dominant_dimension = normalize_dimension_name(payload.get("dominant_dimension")) or inferred_dom
    dominant_dimension_score = clamp_score(payload.get("dominant_dimension_score")) #this cleans the domniant score
#this checks if the domniant score actually matches the highest of the three scores
    if dominant_dimension_score != max(scores.values()):
        dominant_dimension_score = inferred_score
#clean the alternative dimension
    alternative_dimension = normalize_dimension_name(payload.get("alternative_dimension")) or inferred_alt
#clean confidence
    try:
        confidence = round(float(payload.get("confidence", 0.5)), 4) #this tries to extract a numeric value if not the it sets to the default of 0.5
    except Exception:
        confidence = 0.5
    confidence = max(0.0, min(1.0, confidence)) #this forces teh ranges from 0.0 to 1.0
#this cleans the reason
    reason = " ".join(str(payload.get("reason", "")).split()).strip() or "model response"

#this returns the final clean dict
    return {
        "row_id": int(row_id),
        "informativeness": scores["informativeness"],
        "expressiveness": scores["expressiveness"],
        "phatic": scores["phatic"],
        "dominant_dimension": dominant_dimension,
        "dominant_dimension_score": dominant_dimension_score,
        "confidence": confidence,
        "alternative_dimension": alternative_dimension,
        "reason": reason,
        "model_name": model_name,
    }

# %% [markdown]
# These words increases the informativeness score

# %%
INFORMATIVE_KEYWORDS = [
    "offre", "offres", "prix", "euro", "euros", "loyer", "loyers",
    "à partir de", "partir de", "conditions", "condition", "sous condition",
    "garantie", "reprise", "bonus", "prime", "financement", "location",
    "lld", "durée", "entretien", "inclus", "option", "options",
    "autonomie", "recharge", "recharger", "rechargée", "électrique", "electrique",
    "hybride", "batterie", "consommation", "émission", "emission", "co2",
    "technologie", "innovation", "système", "systeme", "connectée", "connecte",
    "navigation", "véhicule", "vehicule", "modèle", "modele", "gamme",
    "réseau", "reseau", "particuliers", "achat", "valable", "ttc", "km"
]

# %% [markdown]
# These words increases the expressiveness score

# %%
EXPRESSIVE_KEYWORDS = [
    "émotion", "emotion", "passion", "désir", "desir", "rêve", "reve",
    "plaisir", "style", "design", "élégance", "elegance", "beauté", "beaute",
    "séduction", "seduction", "unique", "prestige", "luxe", "liberté", "liberte",
    "joie", "sensation", "chance", "incroyable", "exceptionnel", "audace",
    "charisme", "humour", "étonnant", "etonnant", "surprise", "suspense"
]

# %% [markdown]
# These words increases the phatic score

# %%
PHATIC_KEYWORDS = [
    "avec vous", "pour vous", "près de vous", "pres de vous", "à vos côtés",
    "a vos cotes", "ensemble", "au quotidien", "quotidien", "toujours",
    "partenaire", "bienvenue", "bonjour", "famille", "partage", "proche",
    "proximité", "proximite", "service", "réseau", "reseau", "nous accompagnons",
    "nous sommes", "pour toute la famille", "à votre service", "a votre service"
]

# %% [markdown]
# regex patterns that detect direct address

# %%
DIRECT_ADDRESS_PATTERNS = [
    r"\bvous\b", r"\bvotre\b", r"\bvos\b",
    r"\btu\b", r"\btoi\b", r"\bte\b",
    r"\bton\b", r"\bta\b", r"\btes\b",
    r"\bnous\b", r"\bnotre\b", r"\bnos\b",
    r"\bensemble\b"
]

# %% [markdown]
# #Rule-based baseline plus optional real-model backend

# %% [markdown]
# This function is building a first rough score for one ad using rules instead of a real model.

# %%
def baseline_prediction(row, model_name, columns):
    text = build_combined_text(row, columns=columns).lower() #this creates a big text block from the row adn converts it into lowercase, combiens the metadata and selected text columns
    metadata = {key: row.get(key) for key in row.index} #this creates a dict containing all values from the row
#this counts how many times the words from that columns appeared
    info_raw = sum(text.count(k) for k in INFORMATIVE_KEYWORDS)
    expr_raw = sum(text.count(k) for k in EXPRESSIVE_KEYWORDS)
    phat_raw = sum(text.count(k) for k in PHATIC_KEYWORDS)
#this counts how many numbers appeared
    number_hits = len(re.findall(r"\b\d+(?:[.,]\d+)?\b", text))
#this counts exclamation
    exclamation_hits = text.count("!")
#this counts direct addresses
    direct_hits = sum(len(re.findall(pattern, text)) for pattern in DIRECT_ADDRESS_PATTERNS)
    info_raw += min(number_hits, 5) * 0.4 #this adds a bonus to the informativeness up to 5 numbers
    expr_raw += min(exclamation_hits, 3) * 0.5 #this adds a bonus to the expresivenss up to 3 exclamation
    phat_raw += min(direct_hits, 5) * 0.35 #this adds a bonus to the phatic up to 5 direct_hints

#this two are bonuses of 1 if the metadata contains electric and 0.7 if the metadata contains hybrid
    if str(metadata.get("Electric", "")).strip() == "1":
        info_raw += 1.0
    if str(metadata.get("Hybrid", "")).strip() == "1":
        info_raw += 0.7


#This part takes the raw scores you already computed and turns them into the final prediction.
    def raw_to_scale(value):

  #this returns the raw score into 1 to 5 scale
        if value < 0.8:
            return 1
        if value < 2.0:
            return 2
        if value < 3.6:
            return 3
        if value < 5.5:
            return 4
        return 5
#this converts each row score into a clean 1 to 5 score
    scores = {
        "informativeness": raw_to_scale(info_raw),
        "expressiveness": raw_to_scale(expr_raw),
        "phatic": raw_to_scale(phat_raw),
    }
#this uses the scores dict to find the dominant dimension, its score and the alternative
    dominant_dimension, dominant_score, alt = pick_dominant_dimension(scores)

    ranked = sorted([info_raw, expr_raw, phat_raw], reverse=True) #this sorts the raw scores from highest to lowest.
    top = ranked[0] if ranked else 0.0 #this gets teh highest score
    second = ranked[1] if len(ranked) > 1 else 0.0#this gets the sceond highest score
    gap = max(0.0, top - second) #this calculates the difference between them

#this creates a confidence score, which increases when the top is clearly ahead and is the dominant score is high
    confidence = 0.35 + min(gap, 3.0) * 0.12 + dominant_score * 0.05
#if it is a tie the confidence decrease
    if dominant_dimension == "mixed":
        confidence -= 0.12
    confidence = round(max(0.25, min(0.95, confidence)), 4)

#this creates a list for explanation
    reason_bits = []

#if informativeness raw score is sring enough put that explanation, the same for the others
    if info_raw >= 1.5:
        reason_bits.append("factual/technical cues")
    if expr_raw >= 1.5:
        reason_bits.append("emotive/style cues")
    if phat_raw >= 1.2:
        reason_bits.append("bonding/direct-address cues")
    if not reason_bits:
        reason_bits.append("low lexical evidence")
#this is the final prediction output
    return {
        "row_id": int(row["row_id"]),
        "informativeness": scores["informativeness"],
        "expressiveness": scores["expressiveness"],
        "phatic": scores["phatic"],
        "dominant_dimension": dominant_dimension,
        "dominant_dimension_score": dominant_score,
        "confidence": confidence,
        "alternative_dimension": alt,
        "reason": "; ".join(reason_bits),
        "model_name": model_name,
    }

# %% [markdown]
# this function tries to find and extract a JSON object from a model’s text output.

# %%
def extract_json_object(text):
    fenced = re.search(r"```(?:json)?\s*(\{.*?\})\s*```", text, flags=re.DOTALL) #this is looking for JSONobject inside the fenced code block
    candidates = [fenced.group(1)] if fenced else [] #if json found add the inside JSON part to the list cadidatesm if not start with an empty list
    candidates.append(text) #this adds the full text as another candidate.

    decoder = json.JSONDecoder() #JSON decoder
    for candidate in candidates:
        for match in re.finditer(r"\{", candidate): #look for every {, since there is the place from where JSON starts
  #We tried to decode it
            try:
                payload, _ = decoder.raw_decode(candidate[match.start():].strip()) #this tries to parse th JSON file
                if isinstance(payload, dict): #if it a dict returns it
                    return payload
            except json.JSONDecodeError: #if it files keep trying
                continue
    raise ValueError("Could not extract JSON from model output.") #if nothing work raise this error

# %% [markdown]
# This function loads a text-generation model from transformers and keeps it in memory so it does not need to be reloaded every time.

# %%
#this is useful to save time and memory churn
@lru_cache(maxsize=4) # cache decorator, when the cache is full prioritizes removing the least recently used items and it can remember up to 4 different model loads
#this loads teh model
def load_generator(model_id):
    from transformers import pipeline as hf_pipeline #this is the convenient way to load adn run the model
#this loads the generation pipeline
    return hf_pipeline(
        task="text-generation",
        model=model_id,
        tokenizer=model_id,
        trust_remote_code=True, #this lets the HF use costum code and it is necessary for newer models
        device_map="auto", #this lets teh Hf decides wherher to use GPU and CPU
    )

# %% [markdown]
# This function runs the model on your prompt

# %%
def run_transformers_backend(prompt, model_id):
    generator = load_generator(model_id) #gets the model text-generation pipeline for the model, since load_generator is cached it usually reload the model every time, so this is why we use generator
#this sends the prompt to the model and asks it to generate an answer.
    outputs = generator(
        prompt,
        max_new_tokens=MAX_NEW_TOKENS,
        do_sample=False, #this avoids sample randomly
        temperature=0.0, #pushes the model toward a very deterministic answer
        return_full_text=False, #means return only the newly generated answer
    )

#this checks if the model returns nothing, if this is the case the model raise an error
    if not outputs:
        raise RuntimeError("Model returned no output.")
#this cleans it
    return str(outputs[0].get("generated_text", "")).strip()

# %% [markdown]
# This function takes the raw text returned by the model and turns it into a clean prediction dictionary.

# %%
def parse_model_prediction(raw_text, row_id, model_name):
    payload = extract_json_object(raw_text) #extract JSON from the model output
    return coerce_prediction_dict(payload, row_id=row_id, model_name=model_name) #this cleans and validates it

# %% [markdown]
# #Gemma and Mistral models

# %% [markdown]
# This builds the first annotater that is based on Gemma modelv4

# %%
#this function bulid the prompt that will be sent to Gemma for on ad
def build_gemma_prompt(row): #this takes as input one row
    return f"""You are the primary annotator for car advertisements.

{RUBRIC_TEXT}

{SUPERVISOR_NOTES}

{output_schema_text()}

Metadata:
{build_metadata_text(row)}

Ad Content:
{build_record_text(row, TEXT_COLUMNS)}
"""

# %% [markdown]
# This model builds the second annotater prompt that is based on Mistral last version

# %%
def build_mistral_prompt(row, gemma_prediction):
    return f"""You are the second annotator for car advertisements.

Check the Gemma proposal carefully, but do not copy it blindly.
You may agree or disagree.

{RUBRIC_TEXT}

{SUPERVISOR_NOTES}

Gemma proposal:
- informativeness: {gemma_prediction["informativeness"]}
- expressiveness: {gemma_prediction["expressiveness"]}
- phatic: {gemma_prediction["phatic"]}
- dominant_dimension: {gemma_prediction["dominant_dimension"]}
- dominant_dimension_score: {gemma_prediction["dominant_dimension_score"]}
- confidence: {gemma_prediction["confidence"]}

{output_schema_text()}

Metadata:
{build_metadata_text(row)}

Focused Ad Content:
{build_record_text(row, MISTRAL_FOCUS_COLUMNS)}
"""

# %% [markdown]
# How Gemma’s prediction is produced for one row.

# %%
def predict_with_gemma(row):
#this uses the baseline rule-based prediction if the model is not called
    if not RUN_REAL_MODELS:
        return baseline_prediction(row, model_name=GEMMA_MODEL, columns=TEXT_COLUMNS)

    prompt = build_gemma_prompt(row)
#Run Gemma
    try:
        raw_text = run_transformers_backend(prompt, model_id=GEMMA_MODEL) #this sends the prompt to Gemma using HF
        return parse_model_prediction(raw_text, row_id=int(row["row_id"]), model_name=GEMMA_MODEL) #this cleans it
    except Exception as e:
        pred = baseline_prediction(row, model_name=GEMMA_MODEL, columns=TEXT_COLUMNS) #instead od crashing it creates a baseline prediction
        pred["reason"] = f"fallback after Gemma error: {e}; {pred['reason']}" #this updates the explanation
        return pred

# %% [markdown]
# this function makes Mistral act as the verifier for Gemma’s prediction.

# %%
def verify_with_mistral(row, gemma_prediction):
#this is the same idea as before, but this time for Mistral
    if not RUN_REAL_MODELS:
        mistral_pred = baseline_prediction(row, model_name=MISTRAL_MODEL, columns=MISTRAL_FOCUS_COLUMNS)
    else:
        prompt = build_mistral_prompt(row, gemma_prediction)
        try:
            raw_text = run_transformers_backend(prompt, model_id=MISTRAL_MODEL)
            mistral_pred = parse_model_prediction(raw_text, row_id=int(row["row_id"]), model_name=MISTRAL_MODEL)
        except Exception as exc:
            mistral_pred = baseline_prediction(row, model_name=MISTRAL_MODEL, columns=MISTRAL_FOCUS_COLUMNS)
            mistral_pred["reason"] = f"fallback after Mistral error: {exc}; {mistral_pred['reason']}"
#this calculates the score differences between the two models
    deltas = {
        "informativeness": abs(gemma_prediction["informativeness"] - mistral_pred["informativeness"]),
        "expressiveness": abs(gemma_prediction["expressiveness"] - mistral_pred["expressiveness"]),
        "phatic": abs(gemma_prediction["phatic"] - mistral_pred["phatic"]),
    }

    avg_delta = round(sum(deltas.values()) / 3.0, 4)#this computes the avg disagreement
    max_delta = max(deltas.values())#this gets the max disagreement

#this decides if the two models agree with eachother, they agree if they have the same dominant dimension and the biggest score difference is at most 1
    agrees = (
        gemma_prediction["dominant_dimension"] == mistral_pred["dominant_dimension"]
        and max_delta <= 1
    )
#this returns the results of Mistral
    return {
        "row_id": int(row["row_id"]),
        "mistral_informativeness": mistral_pred["informativeness"],
        "mistral_expressiveness": mistral_pred["expressiveness"],
        "mistral_phatic": mistral_pred["phatic"],
        "mistral_dominant_dimension": mistral_pred["dominant_dimension"],
        "mistral_dominant_dimension_score": mistral_pred["dominant_dimension_score"],
        "mistral_confidence": mistral_pred["confidence"],
        "agrees_with_gemma": agrees,
        "avg_score_delta": avg_delta,
        "max_score_delta": max_delta,
        "disagreement_reason": (
            "Gemma and Mistral align on dominant dimension with small score differences"
            if agrees else
            f"Gemma={gemma_prediction['dominant_dimension']} vs Mistral={mistral_pred['dominant_dimension']}; deltas={deltas}"
        ),
        "model_name": MISTRAL_MODEL,
    }

# %% [markdown]
# Test lines

# %%
#this runs the two models on one row and it dsplays the results as a vertical tabel
example = load_rows(limit=1, review_status="needs_label").iloc[0]
gemma_example = predict_with_gemma(example)
mistral_example = verify_with_mistral(example, gemma_example)
pd.DataFrame([gemma_example]).T #this inspect Gemma
pd.DataFrame([mistral_example]).T #this inspect Mistral
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#                                                                                   0
# row_id                                                                         2100
# mistral_informativeness                                                           4
# mistral_expressiveness                                                            3
# mistral_phatic                                                                    2
# mistral_dominant_dimension                                          informativeness
# mistral_dominant_dimension_score                                                  4
# mistral_confidence                                                             0.67
# agrees_with_gemma                                                             False
# avg_score_delta                                                              0.3333
# max_score_delta                                                                   1
# disagreement_reason               Gemma=mixed vs Mistral=informativeness; deltas...
# model_name                                mistralai/Mistral-Small-4-119B-2603-eagle

# %% [markdown]
# #Router

# %%
ROUTER_FEATURES = [
    "gemma_confidence",
    "mistral_confidence",
    "dominant_agreement",
    "gemma_top_gap",
    "mistral_top_gap",
    "avg_score_delta",
    "max_score_delta",
    "informativeness_delta",
    "expressiveness_delta",
    "phatic_delta",
]

# %% [markdown]
# how much the top score is ahead of the second-best score

# %%
#this orders the dimension scores
def top_gap_from_scores(a, b, c):
    scores = sorted([int(a), int(b), int(c)], reverse=True) #sort them from highest to lowest and convert them in int
    return scores[0] - scores[1] #the model is more decisive if the gap is larg and small gap means uncertain

# %% [markdown]
#  router input table

# %%
def build_router_feature_frame(gemma_df, mistral_df):
    merged = gemma_df.merge(mistral_df, on="row_id", how="inner") #this applies inner join on Mistral and Gemma DFs
    merged["gemma_confidence"] = merged["confidence"].astype(float) #this cleans the confidence
    merged["mistral_confidence"] = merged["mistral_confidence"].astype(float) #sane thing
    merged["dominant_agreement"] = (
        merged["dominant_dimension"] == merged["mistral_dominant_dimension"]
    ).astype(int) # thus checks if the two agree for the dominant dimension, if yes is Truem which is 1 and 0 if it is False
#this two computes for Gemma and Mistral the difference between highest score and its second-highest score
    merged["gemma_top_gap"] = merged.apply(
        lambda r: top_gap_from_scores(r["informativeness"], r["expressiveness"], r["phatic"]), axis=1
    )
    merged["mistral_top_gap"] = merged.apply(
        lambda r: top_gap_from_scores(r["mistral_informativeness"], r["mistral_expressiveness"], r["mistral_phatic"]), axis=1
    )


#these three compute the disagreement between the two models
    merged["informativeness_delta"] = (merged["informativeness"] - merged["mistral_informativeness"]).abs()
    merged["expressiveness_delta"] = (merged["expressiveness"] - merged["mistral_expressiveness"]).abs()
    merged["phatic_delta"] = (merged["phatic"] - merged["mistral_phatic"]).abs()

    return merged

# %% [markdown]
# The router itself that decides the final thing to do

# %%
def route_row(row):
    gemma_conf = float(row["gemma_confidence"]) #confidence value of Gemma
    mistral_conf = float(row["mistral_confidence"]) #confidence value of Mistral
    agrees = bool(row["dominant_agreement"]) #the dominant
    avg_delta = float(row["avg_score_delta"])
    hard_delta = int(row["max_score_delta"])
    mean_conf = (gemma_conf + mistral_conf) / 2.0 #the mean confidence

#this is the accept score which is calculated by introducing mean confidence, the agreement of the dominant decison and its disagreement between the models
    accept_score = (
        mean_conf * 0.55
        + float(agrees) * 0.30
        + (1.0 - min(avg_delta / 4.0, 1.0)) * 0.15
    )
    accept_score = round(max(0.0, min(1.0, accept_score)), 4) # this gives the range 0.0 to 1.0


#this decides whether to automatically accept
    if (
        agrees
        and gemma_conf >= ROUTER_ACCEPT_THRESHOLD # the two must agree
        and mistral_conf >= ROUTER_REVIEW_THRESHOLD # the confidence of Gemma has to be enough
        and avg_delta <= ROUTER_MAX_AVG_SCORE_DELTA #the confidence of Mistral has to be enough
        and hard_delta <= 1 #the disagreement
    ):
#this is its return
        return {
            "row_id": int(row["row_id"]),
            "route_action": "accept",
            "route_score": accept_score,
            "route_reason": "Gemma and Mistral align with strong confidence and low score drift",
        }


#decide if it is needed to ask a human

    if (
        gemma_conf <= ROUTER_HUMAN_THRESHOLD #Gemma confidence is low
        or mistral_conf <= ROUTER_HUMAN_THRESHOLD #Mistral confidence is low
        or (not agrees and hard_delta >= ROUTER_MAX_HARD_DELTA) #they disagree and one disagreement is high
    ):
#this is the return if that previous thing is accepted
        return {
            "row_id": int(row["row_id"]),
            "route_action": "ask_human",
            "route_score": round(max(1.0 - mean_conf, min(hard_delta / 3.0, 1.0), 0.55 if not agrees else 0.0), 4),
            "route_reason": "confidence is too low or Gemma and Mistral diverge too strongly",
        }


#this is the return for send to review if the conditions from above are not respected
    return {
        "row_id": int(row["row_id"]),
        "route_action": "send_to_review",
        "route_score": round(min(0.95, 0.50 + (0.15 if not agrees else 0.0) + min(avg_delta / 4.0, 1.0) * 0.15), 4),
        "route_reason": "worth reviewing before acceptance",
    }

# %% [markdown]
# This function tries to load a previously saved router model from disk

# %%
def load_router_policy():
    if not POLICY_PATH.exists():
        return None
    with POLICY_PATH.open("rb") as f: #this both reads and it is binary since the pickle files are binary
        return pickle.load(f)

# %% [markdown]
# This function trains a router model from a feedback CSV and saves it to disk.

# %%
def train_router_policy(feedback_csv_path):
    feedback = pd.read_csv(feedback_csv_path) # loads the data

#checks that route_label exists
    if "route_label" not in feedback.columns:
        raise ValueError("Feedback CSV must include route_label.")
#checks that all router features exist
    if not set(ROUTER_FEATURES).issubset(feedback.columns):
        raise ValueError("Feedback CSV is missing router feature columns.")
#this is a standerdiser and the Logistic Regression model to choose between these 3 labels of the router
    model = Pipeline(
        steps=[
            ("scale", StandardScaler()),
            ("clf", LogisticRegression(max_iter=2000, class_weight="balanced", random_state=42)),
        ]
    )
    model.fit(feedback[ROUTER_FEATURES], feedback["route_label"]) #this train it, model learns from features and predict the route label

    with POLICY_PATH.open("wb") as f: #this time to save it we use write and binary for pickle
        pickle.dump({"feature_columns": ROUTER_FEATURES, "model": model}, f) #this saves it

    return POLICY_PATH

# %% [markdown]
# This function runs the router step of the pipeline

# %%
def run_router(gemma_df, mistral_df):
    feature_df = build_router_feature_frame(gemma_df, mistral_df) #this builds the outputs of teh two models and it computes the router features
    policy = load_router_policy() #if there is a policy model it uses it, if not is None
#if is None it will use rule-based routing
    if policy is None:
        router_rows = [route_row(row) for _, row in feature_df.iterrows()]
        return pd.DataFrame(router_rows), feature_df

# if the trained policy exists use it
    probs = policy["model"].predict_proba(feature_df[policy["feature_columns"]])
    classes = list(policy["model"].classes_) #this returns the class names
    best_idx = probs.argmax(axis=1)#index of highest proba

    rows = []
    for row, idx, prob_row in zip(feature_df.itertuples(index=False), best_idx, probs): #this loops through everything
#this is the final dicts
        rows.append({
            "row_id": int(row.row_id),
            "route_action": str(classes[idx]),
            "route_score": round(float(prob_row[idx]), 4),
            "route_reason": "trained router policy",
        })
    return pd.DataFrame(rows), feature_df

# %% [markdown]
# #End-to-end run and save outputs

# %% [markdown]
# This is the whole workflow from start to finish

# %%
def run_annotation_pipeline(limit=20, review_status="needs_label"): #this process only 20 rows and use only rows where review_status="needs_label"
    source_rows = load_rows(limit=limit, review_status=review_status) #this is using the fun created above to loads the rows
    gemma_rows = []
    mistral_rows = []

    for _, row in source_rows.iterrows(): #we loop through selected ads
        gemma_prediction = predict_with_gemma(row) #this get Gemma annotation
        mistral_decision = verify_with_mistral(row, gemma_prediction) #this gets the Mistral annotation +

        gemma_rows.append(gemma_prediction)
        mistral_rows.append(mistral_decision)
#converts them to DF
    gemma_df = pd.DataFrame(gemma_rows)
    mistral_df = pd.DataFrame(mistral_rows)
#this runs the router
    router_df, router_features_df = run_router(gemma_df, mistral_df)

#this creates a combined table
    combined_df = (
        gemma_df
        .merge(mistral_df, on="row_id", how="inner")
        .merge(router_df, on="row_id", how="inner")
    )
#this defines the output file paths

    gemma_path = OUTPUT_DIR / "gemma_predictions.csv"
    mistral_path = OUTPUT_DIR / "mistral_decisions.csv"
    router_path = OUTPUT_DIR / "router_actions.csv"
    combined_path = OUTPUT_DIR / "combined_decisions.csv"
    feature_path = OUTPUT_DIR / "router_features.csv"

#this save each output to CSV
    gemma_df.to_csv(gemma_path, index=False)
    mistral_df.to_csv(mistral_path, index=False)
    router_df.to_csv(router_path, index=False)
    combined_df.to_csv(combined_path, index=False)
    router_features_df.to_csv(feature_path, index=False)
#we print where the files were saved
    print("wrote", gemma_path)
    print("wrote", mistral_path)
    print("wrote", router_path)
    print("wrote", combined_path)
    print("wrote", feature_path)

    return gemma_df, mistral_df, router_df, combined_df, router_features_df

# %% [markdown]
# #This excutes the whole pipeline

# %%
gemma_df, mistral_df, router_df, combined_df, router_features_df = run_annotation_pipeline(
    limit=20,
    review_status="needs_label",
)

print(router_df["route_action"].value_counts(dropna=False)) #this shows the route counts
combined_df.head(20)
# Out:
# wrote /content/drive/MyDrive/Gliner-Work.Dauphine/communication_function_outputs/gemma_predictions.csv
# wrote /content/drive/MyDrive/Gliner-Work.Dauphine/communication_function_outputs/mistral_decisions.csv
# wrote /content/drive/MyDrive/Gliner-Work.Dauphine/communication_function_outputs/router_actions.csv
# wrote /content/drive/MyDrive/Gliner-Work.Dauphine/communication_function_outputs/combined_decisions.csv
# wrote /content/drive/MyDrive/Gliner-Work.Dauphine/communication_function_outputs/router_features.csv
# route_action
# accept            9
# send_to_review    6
# ask_human         5
# Name: count, dtype: int64
#     row_id  informativeness  expressiveness  phatic dominant_dimension  \
# 0     2100                4               4       2              mixed
# 1     2101                3               5       2     expressiveness
# 2     2102                5               3       5              mixed
# 3     2103                5               5       2              mixed
# 4     2104                5               2       3    informativeness
# 5     2105                5               3       2    informativeness
# 6     2106                3               5       2     expressiveness
# 7     2107                5               5       2              mixed
# 8     2108                5               4       2    informativeness
# 9     2109                4               1       3    informativeness
# 10    2110                4               1       3    informativeness
# 11    2111                5               5       2              mixed
# 12    2112                3               2       1    informativeness
# 13    2113                4               3       4              mixed
# 14    2114                5               1       1    informativeness
# 15    2115                3               2       1    informativeness
# 16    2116                5               3       1    informativeness
# 17    2117                5               2       3    informativeness
# 18    2118                5               3       1    informativeness
# 19    2119                5               2       3    informativeness
#
#     dominant_dimension_score  confidence alternative_dimension  \
# 0                          4       0.550        expressiveness
# 1                          5       0.950       informativeness
# 2                          5       0.840                phatic
# 3                          5       0.840        expressiveness
# 4                          5       0.950                phatic
# 5                          5       0.950        expressiveness
# 6                          5       0.950       informativeness
# 7                          5       0.840        expressiveness
# 8                          5       0.950        expressiveness
# 9                          4       0.910                phatic
# 10                         4       0.790                phatic
# 11                         5       0.840        expressiveness
# 12                         3       0.740        expressiveness
# 13                         4       0.508                phatic
# 14                         5       0.950        expressiveness
# 15                         3       0.620        expressiveness
# 16                         5       0.950        expressiveness
# 17                         5       0.950                phatic
# 18                         5       0.950        expressiveness
# 19                         5       0.950                phatic
#
#                                                reason           model_name_x  \
# 0   fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 1   fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 2   fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 3   fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 4   fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 5   fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 6   fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 7   fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 8   fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 9   fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 10  fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 11  fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 12  fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 13  fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 14  fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 15  fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 16  fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 17  fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 18  fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
# 19  fallback after Gemma error: The checkpoint you...  google/gemma-4-E4B-it
#
#     ...  mistral_dominant_dimension_score  mistral_confidence  \
# 0   ...                                 4               0.670
# 1   ...                                 3               0.560
# 2   ...                                 5               0.950
# 3   ...                                 5               0.950
# 4   ...                                 5               0.950
# 5   ...                                 5               0.950
# 6   ...                                 3               0.560
# 7   ...                                 5               0.950
# 8   ...                                 5               0.950
# 9   ...                                 4               0.910
# 10  ...                                 4               0.910
# 11  ...                                 5               0.950
# 12  ...                                 3               0.740
# 13  ...                                 4               0.508
# 14  ...                                 5               0.950
# 15  ...                                 3               0.698
# 16  ...                                 5               0.950
# 17  ...                                 5               0.950
# 18  ...                                 5               0.950
# 19  ...                                 5               0.950
#
#     agrees_with_gemma avg_score_delta  max_score_delta  \
# 0               False          0.3333                1
# 1               False          0.6667                2
# 2               False          0.6667                1
# 3               False          0.6667                2
# 4                True          0.0000                0
# 5                True          0.3333                1
# 6               False          0.6667                2
# 7               False          1.0000                2
# 8                True          0.6667                1
# 9                True          0.0000                0
# 10               True          0.0000                0
# 11              False          0.6667                2
# 12               True          0.0000                0
# 13               True          0.3333                1
# 14               True          0.0000                0
# 15               True          0.3333                1
# 16               True          0.3333                1
# 17               True          0.3333                1
# 18               True          0.0000                0
# 19               True          0.3333                1
#
#                                   disagreement_reason  \
# 0   Gemma=mixed vs Mistral=informativeness; deltas...
# 1   Gemma=expressiveness vs Mistral=mixed; deltas=...
# 2   Gemma=mixed vs Mistral=informativeness; deltas...
# 3   Gemma=mixed vs Mistral=informativeness; deltas...
# 4   Gemma and Mistral align on dominant dimension ...
# 5   Gemma and Mistral align on dominant dimension ...
# 6   Gemma=expressiveness vs Mistral=mixed; deltas=...
# 7   Gemma=mixed vs Mistral=informativeness; deltas...
# 8   Gemma and Mistral align on dominant dimension ...
# 9   Gemma and Mistral align on dominant dimension ...
# 10  Gemma and Mistral align on dominant dimension ...
# 11  Gemma=mixed vs Mistral=informativeness; deltas...
# 12  Gemma and Mistral align on dominant dimension ...
# 13  Gemma and Mistral align on dominant dimension ...
# 14  Gemma and Mistral align on dominant dimension ...
# 15  Gemma and Mistral align on dominant dimension ...
# 16  Gemma and Mistral align on dominant dimension ...
# 17  Gemma and Mistral align on dominant dimension ...
# 18  Gemma and Mistral align on dominant dimension ...
# 19  Gemma and Mistral align on dominant dimension ...
#
#                                  model_name_y    route_action  route_score  \
# 0   mistralai/Mistral-Small-4-119B-2603-eagle  send_to_review       0.6625
# 1   mistralai/Mistral-Small-4-119B-2603-eagle       ask_human       0.6667
# 2   mistralai/Mistral-Small-4-119B-2603-eagle  send_to_review       0.6750
# 3   mistralai/Mistral-Small-4-119B-2603-eagle       ask_human       0.6667
# 4   mistralai/Mistral-Small-4-119B-2603-eagle          accept       0.9725
# 5   mistralai/Mistral-Small-4-119B-2603-eagle          accept       0.9600
# 6   mistralai/Mistral-Small-4-119B-2603-eagle       ask_human       0.6667
# 7   mistralai/Mistral-Small-4-119B-2603-eagle       ask_human       0.6667
# 8   mistralai/Mistral-Small-4-119B-2603-eagle          accept       0.9475
# 9   mistralai/Mistral-Small-4-119B-2603-eagle          accept       0.9505
# 10  mistralai/Mistral-Small-4-119B-2603-eagle  send_to_review       0.5000
# 11  mistralai/Mistral-Small-4-119B-2603-eagle       ask_human       0.6667
# 12  mistralai/Mistral-Small-4-119B-2603-eagle  send_to_review       0.5000
# 13  mistralai/Mistral-Small-4-119B-2603-eagle  send_to_review       0.5125
# 14  mistralai/Mistral-Small-4-119B-2603-eagle          accept       0.9725
# 15  mistralai/Mistral-Small-4-119B-2603-eagle  send_to_review       0.5125
# 16  mistralai/Mistral-Small-4-119B-2603-eagle          accept       0.9600
# 17  mistralai/Mistral-Small-4-119B-2603-eagle          accept       0.9600
# 18  mistralai/Mistral-Small-4-119B-2603-eagle          accept       0.9725
# 19  mistralai/Mistral-Small-4-119B-2603-eagle          accept       0.9600
#
#                                          route_reason
# 0                   worth reviewing before acceptance
# 1   confidence is too low or Gemma and Mistral div...
# 2                   worth reviewing before acceptance
# 3   confidence is too low or Gemma and Mistral div...
# 4   Gemma and Mistral align with strong confidence...
# 5   Gemma and Mistral align with strong confidence...
# 6   confidence is too low or Gemma and Mistral div...
# 7   confidence is too low or Gemma and Mistral div...
# 8   Gemma and Mistral align with strong confidence...
# 9   Gemma and Mistral align with strong confidence...
# 10                  worth reviewing before acceptance
# 11  confidence is too low or Gemma and Mistral div...
# 12                  worth reviewing before acceptance
# 13                  worth reviewing before acceptance
# 14  Gemma and Mistral align with strong confidence...
# 15                  worth reviewing before acceptance
# 16  Gemma and Mistral align with strong confidence...
# 17  Gemma and Mistral align with strong confidence...
# 18  Gemma and Mistral align with strong confidence...
# 19  Gemma and Mistral align with strong confidence...
#
# [20 rows x 24 columns]
